# %% [markdown]
# <a href="https://colab.research.google.com/github/pankaj-beldar/Bearing-Stability-detection/blob/main/bearing_stable_unstable_graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **capillary Stable**

# %%
import pandas as pd
df=pd.read_excel('/content/drive/MyDrive/Bearing/cappilary stable.xlsx')
df
# Out:
#           a       b  del  w     Mj   x  y  Cluster_Labels
# 0    0.0500  0.0500  1.2  2  0.9Mc  18  3               1
# 1    0.0366  0.0533  1.2  2  0.9Mc  18  3               1
# 2    0.0116  0.0541  1.2  2  0.9Mc  18  3               1
# 3   -0.0144  0.0444  1.2  2  0.9Mc  18  3               1
# 4   -0.0353  0.0264  1.2  2  0.9Mc  18  3               1
# ..      ...     ...  ... ..    ...  .. ..             ...
# 385  0.0279 -0.0180  1.2  3  1.1Mc   1  1               0
# 386  0.0302  0.0030  1.2  3  1.1Mc   1  1               0
# 387  0.0224  0.0212  1.2  3  1.1Mc   1  1               0
# 388  0.0040  0.0333  1.2  3  1.1Mc   1  1               0
# 389 -0.0181  0.0352  1.2  3  1.1Mc   1  1               0
#
# [390 rows x 8 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Replace df with your actual DataFrame name

# Scatter plot between columns 'a' and 'b'
plt.figure(figsize=(8, 6))
plt.scatter(df['a'], df['b'], color='blue', alpha=0.7)
plt.title('Scatter plot of a vs b')
plt.xlabel('Column a')
plt.ylabel('Column b')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Replace df with your actual DataFrame name

# Extracting 'a' and 'b' columns in sets of 30 readings
num_readings = 30
total_rows = len(df)
num_sets = total_rows // num_readings

# Plotting in sets of 30 readings
plt.figure(figsize=(10, 6))
for i in range(num_sets):
    start_idx = i * num_readings
    end_idx = start_idx + num_readings
    subset = df.iloc[start_idx:end_idx]
    plt.plot(subset['a'], subset['b'], label=f'Set {i+1}')

plt.title('Plot of a and b in sets of 30 readings')
plt.xlabel('Column a')
plt.ylabel('Column b')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Replace df with your actual DataFrame name

num_readings = 30
total_rows = len(df)
num_sets = total_rows // num_readings

fig, axes = plt.subplots(num_sets, figsize=(8, 5*num_sets))

for i, ax in enumerate(axes.flatten()):
    start_idx = i * num_readings
    end_idx = start_idx + num_readings
    subset = df.iloc[start_idx:end_idx]

    del_val = subset['del'].values[0]
    w_val = subset['w'].values[0]
    Mj_val = subset['Mj'].values[0]
    x_val = subset['x'].values[0]
    y_val = subset['y'].values[0]

    ax.plot(subset['a'], subset['b'])
    ax.set_title(f'Set {i+1}: del={del_val}, w={w_val}, Mj={Mj_val}, x={x_val}, y={y_val}')
    ax.set_xlabel('Column a')
    ax.set_ylabel('Column b')
    ax.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **capillary unstable**

# %%
import pandas as pd
df=pd.read_excel('/content/drive/MyDrive/Bearing/capillary unstable.xlsx')
df
# Out:
#           a       b  del  w     Mj   x  y  Cluster_Labels
# 0    0.0500  0.0500  0.8  3  1.1Mc   1  6               0
# 1    0.0400  0.0479  0.8  3  1.1Mc   1  6               0
# 2    0.0202  0.0415  0.8  3  1.1Mc   1  6               0
# 3   -0.0015  0.0309  0.8  3  1.1Mc   1  6               0
# 4   -0.0206  0.0169  0.8  3  1.1Mc   1  6               0
# ..      ...     ...  ... ..    ...  .. ..             ...
# 295  0.0628 -0.0004  1.2  2  1.1Mc  18  3               1
# 296  0.0611  0.0250  1.2  2  1.1Mc  18  3               1
# 297  0.0446  0.0470  1.2  2  1.1Mc  18  3               1
# 298  0.0217  0.0600  1.2  2  1.1Mc  18  3               1
# 299 -0.0050  0.0592  1.2  2  1.1Mc  18  3               1
#
# [300 rows x 8 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Replace df with your actual DataFrame name

# Scatter plot between columns 'a' and 'b'
plt.figure(figsize=(8, 6))
plt.scatter(df['a'], df['b'], color='red', alpha=0.7)
plt.title('Scatter plot of a vs b')
plt.xlabel('Column a')
plt.ylabel('Column b')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Replace df with your actual DataFrame name

# Extracting 'a' and 'b' columns in sets of 30 readings
num_readings = 30
total_rows = len(df)
num_sets = total_rows // num_readings

# Plotting in sets of 30 readings
plt.figure(figsize=(10, 6))
for i in range(num_sets):
    start_idx = i * num_readings
    end_idx = start_idx + num_readings
    subset = df.iloc[start_idx:end_idx]
    plt.plot(subset['a'], subset['b'], label=f'Set {i+1}')

plt.title('Plot of a and b in sets of 30 readings')
plt.xlabel('Column a')
plt.ylabel('Column b')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Replace df with your actual DataFrame name

num_readings = 30
total_rows = len(df)
num_sets = total_rows // num_readings

fig, axes = plt.subplots(num_sets, figsize=(8, 5*num_sets))

for i, ax in enumerate(axes.flatten()):
    start_idx = i * num_readings
    end_idx = start_idx + num_readings
    subset = df.iloc[start_idx:end_idx]

    del_val = subset['del'].values[0]
    w_val = subset['w'].values[0]
    Mj_val = subset['Mj'].values[0]
    x_val = subset['x'].values[0]
    y_val = subset['y'].values[0]

    ax.plot(subset['a'], subset['b'])
    ax.set_title(f'Set {i+1}: del={del_val}, w={w_val}, Mj={Mj_val}, x={x_val}, y={y_val}')
    ax.set_xlabel('Column a')
    ax.set_ylabel('Column b')
    ax.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Surface stable**

# %%
import pandas as pd
df=pd.read_excel('/content/drive/MyDrive/Bearing/Suraface Stable.xlsx')
df
# Out:
#           a       b  del  w  Mj   x  y  Cluster_Labels
# 0    0.0500  0.0500  0.8  2  Mc   0  0               0
# 1    0.0365  0.0515  0.8  2  Mc   0  0               0
# 2    0.0102  0.0510  0.8  2  Mc   0  0               0
# 3   -0.0173  0.0431  0.8  2  Mc   0  0               0
# 4   -0.0393  0.0272  0.8  2  Mc   0  0               0
# ..      ...     ...  ... ..  ..  .. ..             ...
# 745  0.0184  0.0035  1.2  2  Mc  18  3               1
# 746  0.0131  0.0138  1.2  2  Mc  18  3               1
# 747  0.0047  0.0187  1.2  2  Mc  18  3               1
# 748 -0.0094  0.0197  1.2  2  Mc  18  3               1
# 749 -0.0236  0.0148  1.2  2  Mc  18  3               1
#
# [750 rows x 8 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Replace df with your actual DataFrame name

# Scatter plot between columns 'a' and 'b'
plt.figure(figsize=(8, 6))
plt.scatter(df['a'], df['b'], color='g', alpha=0.7)
plt.title('Scatter plot of a vs b')
plt.xlabel('Column a')
plt.ylabel('Column b')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Replace df with your actual DataFrame name

# Extracting 'a' and 'b' columns in sets of 30 readings
num_readings = 30
total_rows = len(df)
num_sets = total_rows // num_readings

# Plotting in sets of 30 readings
plt.figure(figsize=(10, 6))
for i in range(num_sets):
    start_idx = i * num_readings
    end_idx = start_idx + num_readings
    subset = df.iloc[start_idx:end_idx]
    plt.plot(subset['a'], subset['b'], label=f'Set {i+1}')

plt.title('Plot of a and b in sets of 30 readings')
plt.xlabel('Column a')
plt.ylabel('Column b')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Replace df with your actual DataFrame name

num_readings = 30
total_rows = len(df)
num_sets = total_rows // num_readings

fig, axes = plt.subplots(num_sets, figsize=(8, 5*num_sets))

for i, ax in enumerate(axes.flatten()):
    start_idx = i * num_readings
    end_idx = start_idx + num_readings
    subset = df.iloc[start_idx:end_idx]

    del_val = subset['del'].values[0]
    w_val = subset['w'].values[0]
    Mj_val = subset['Mj'].values[0]
    x_val = subset['x'].values[0]
    y_val = subset['y'].values[0]

    ax.plot(subset['a'], subset['b'])
    ax.set_title(f'Set {i+1}: del={del_val}, w={w_val}, Mj={Mj_val}, x={x_val}, y={y_val}')
    ax.set_xlabel('Column a')
    ax.set_ylabel('Column b')
    ax.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Surface Unsable**

# %%
import pandas as pd
df=pd.read_excel('/content/drive/MyDrive/Bearing/Surface Unstable.xlsx')
df
# Out:
#           a       b  del  w  Mj   x  y  Cluster_Labels
# 0    0.0500  0.0500  0.8  2  Mc  18  3               1
# 1    0.0371  0.0507  0.8  2  Mc  18  3               1
# 2    0.0138  0.0495  0.8  2  Mc  18  3               1
# 3   -0.0084  0.0440  0.8  2  Mc  18  3               1
# 4   -0.0246  0.0350  0.8  2  Mc  18  3               1
# ..      ...     ...  ... ..  ..  .. ..             ...
# 235  0.0419 -0.0070  1.2  3  Mc   1  6               0
# 236  0.0382  0.0171  1.2  3  Mc   1  6               0
# 237  0.0263  0.0343  1.2  3  Mc   1  6               0
# 238  0.0096  0.0416  1.2  3  Mc   1  6               0
# 239 -0.0104  0.0399  1.2  3  Mc   1  6               0
#
# [240 rows x 8 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Replace df with your actual DataFrame name

# Scatter plot between columns 'a' and 'b'
plt.figure(figsize=(8, 6))
plt.scatter(df['a'], df['b'], color='red', alpha=0.7)
plt.title('Scatter plot of a vs b')
plt.xlabel('Column a')
plt.ylabel('Column b')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Replace df with your actual DataFrame name

# Extracting 'a' and 'b' columns in sets of 30 readings
num_readings = 30
total_rows = len(df)
num_sets = total_rows // num_readings

# Plotting in sets of 30 readings
plt.figure(figsize=(10, 6))
for i in range(num_sets):
    start_idx = i * num_readings
    end_idx = start_idx + num_readings
    subset = df.iloc[start_idx:end_idx]
    plt.plot(subset['a'], subset['b'], label=f'Set {i+1}')

plt.title('Plot of a and b in sets of 30 readings')
plt.xlabel('Column a')
plt.ylabel('Column b')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Replace df with your actual DataFrame name

num_readings = 30
total_rows = len(df)
num_sets = total_rows // num_readings

fig, axes = plt.subplots(num_sets, figsize=(8, 5*num_sets))

for i, ax in enumerate(axes.flatten()):
    start_idx = i * num_readings
    end_idx = start_idx + num_readings
    subset = df.iloc[start_idx:end_idx]

    del_val = subset['del'].values[0]
    w_val = subset['w'].values[0]
    Mj_val = subset['Mj'].values[0]
    x_val = subset['x'].values[0]
    y_val = subset['y'].values[0]

    ax.plot(subset['a'], subset['b'])
    ax.set_title(f'Set {i+1}: del={del_val}, w={w_val}, Mj={Mj_val}, x={x_val}, y={y_val}')
    ax.set_xlabel('Column a')
    ax.set_ylabel('Column b')
    ax.grid(True)

plt.tight_layout()
plt.show()
